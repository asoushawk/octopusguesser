# %% [markdown]
# <a href="https://colab.research.google.com/github/asoushawk/octopusguesser/blob/master/prediction_script1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %%
# !pip install -q sklearn

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import time

import tensorflow.compat.v2.feature_column as fc

import tensorflow as tf

# %%
# Load dataset.
dftrain = pd.read_csv('http://unes.epizy.com/treino.csv') # training data
dfeval = pd.read_csv('http://unes.epizy.com/12.csv') # testing data
eval = pd.read_csv('http://unes.epizy.com/12.csv')
y_train = dftrain.pop('winner')
print(dftrain.head())
y_eval = dfeval.pop('winner')
print(dfeval.head())
# Out:
#   top_red_champion  ...  sup_blue_champion_kda
# 0            Yasuo  ...               6.700000
# 1         Renekton  ...               6.700000
# 2         Renekton  ...               2.483333
# 3         Malphite  ...               2.526316
# 4            Fiora  ...               2.153846
#
# [5 rows x 30 columns]
#   top_red_champion  ...  sup_blue_champion_kda
# 0            Yasuo  ...               6.700000
# 1         Renekton  ...               6.700000
# 2         Renekton  ...               2.483333
# 3         Malphite  ...               2.526316
# 4            Fiora  ...               2.153846
#
# [5 rows x 30 columns]

# %%
CATEGORICAL_COLUMNS = []
NUMERIC_COLUMNS = ["top_red_rota_champion_month", "top_red_champion_kda", 
"top_blue_rota_champion_month", "top_blue_champion_kda", 
"jg_red_rota_champion_month",  "jg_red_champion_kda", 
"jg_blue_rota_champion_month",  "jg_blue_champion_kda", 
"mid_red_rota_champion_month", "mid_red_champion_kda", 
"mid_blue_rota_champion_month",  "mid_blue_champion_kda",
"adc_red_rota_champion_month",  "adc_red_champion_kda",
"adc_blue_rota_champion_month",  "adc_blue_champion_kda",
"sup_red_rota_champion_month",  "sup_red_champion_kda",
"sup_blue_rota_champion_month",  "sup_blue_champion_kda"]

feature_columns = []
for feature_name in CATEGORICAL_COLUMNS:
  vocabulary = dftrain[feature_name].unique()  # gets a list of all unique values from given feature column
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
  feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

print(list(feature_columns[1]))
# Out:
# ['top_red_champion_kda', (1,), None, tf.float32, None]

# %%
dftrain.head()
# Out:
#   top_red_champion  ...  sup_blue_champion_kda
# 0            Yasuo  ...               6.700000
# 1         Renekton  ...               6.700000
# 2         Renekton  ...               2.483333
# 3         Malphite  ...               2.526316
# 4            Fiora  ...               2.153846
#
# [5 rows x 30 columns]

# %% [markdown]
# input function

# %%
def make_input_fn(data_df, label_df, num_epochs=1000, shuffle=False, batch_size=32):
  def input_function():  # inner function, this will be returned
    ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))  # create tf.data.Dataset object with data and its label
    if shuffle:
      ds = ds.shuffle(1000)  # randomize order of data
    ds = ds.batch(batch_size).repeat(num_epochs)  # split dataset into batches of 32 and repeat process for number of epochs
    return ds  # return a batch of the dataset
  return input_function  # return a function object for use

train_input_fn = make_input_fn(dftrain, y_train)  # here we will call the input_function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# We create a linear estimtor by passing the feature columns we created earlier
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpc2ggp2oj
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpc2ggp2oj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
linear_est.train(train_input_fn)  # train
result = linear_est.evaluate(eval_input_fn)  # get model metrics/stats by testing on tetsing data

clear_output()  # clears consoke output
print(result['accuracy'])  # the result variable is simply a dict of stats about our model
# Out:
# 0.84615386

# %%
pred_dicts = list(linear_est.predict(eval_input_fn))
probs = pd.Series([pred['probabilities'][1] for pred in pred_dicts])

probs.plot(kind='hist', bins=20, title='predicted probabilities')
# Out:
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpf8frhdzh/model.ckpt-150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
result = list(linear_est.predict(eval_input_fn))
p = 0
redwincount = 0
bluewincount = 0
erros = 0
acertos = 0

for _ in range(103):
  
  winner_ = eval.iat[p,30]
  print(p)
  a = float(result[p]['probabilities'][1])
  b = float(result[p]['probabilities'][0])
  resultblue = round(a,3)
  resultred = round(b,3)
  print(resultblue * 100, "% de chance do time azul vencer")
  print(resultred * 100, "% de chance do time vermelho vencer")
  
  p = p + 1
  print("Acho que o vencedor foi o:", winner_)
 
  
  if resultred > 0.500000:
    redwincount = redwincount + 1
    print("Bluewincount:", bluewincount)
    print("Redwincount:", redwincount)
    if winner_ != 0:
      print("Eu errei, meeeeeeeee")
      erros = erros + 1
      print("Total de erros:", erros)
      print("Total de acertos:", acertos)
    else:
      print("Hmmm analizando o resultado real da partida, eu acertei hihi")
      acertos = acertos + 1
      print("Total de erros:", erros)
      print("Total de acertos:", acertos)

    
  else:
     bluewincount = bluewincount + 1
     print("Bluewincount:", bluewincount)
     print("Redwincount:", redwincount)
     if winner_ != 1:
      print("Eu errei, meeeeeeeeeeeeeee")
      erros = erros + 1
      print("Total de erros:", erros)
      print("Total de acertos:", acertos)
     else:
      print("Hmmm analizando o resultado real da partida, eu acertei hihi")
      acertos = acertos + 1
      print("Total de erros:", erros)
      print("Total de acertos:", acertos)
# Out:
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc2ggp2oj/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 0
# 1.6 % de chance do time azul vencer
# 98.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 0
# Redwincount: 1
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 1
# 1
# 0.4 % de chance do time azul vencer
# 99.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 0
# Redwincount: 2
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 2
# 2
# 9.9 % de chance do time azul vencer
# 90.10000000000001 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 0
# Redwincount: 3
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 3
# 3
# 0.0 % de chance do time azul vencer
# 100.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 0
# Redwincount: 4
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 4
# 4
# 47.699999999999996 % de chance do time azul vencer
# 52.300000000000004 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 0
# Redwincount: 5
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 5
# 5
# 95.89999999999999 % de chance do time azul vencer
# 4.1000000000000005 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 1
# Redwincount: 5
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 6
# 6
# 3.5000000000000004 % de chance do time azul vencer
# 96.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 1
# Redwincount: 6
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 7
# 7
# 99.9 % de chance do time azul vencer
# 0.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 2
# Redwincount: 6
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 0
# Total de acertos: 8
# 8
# 33.300000000000004 % de chance do time azul vencer
# 66.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 2
# Redwincount: 7
# Eu errei, meeeeeeeee
# Total de erros: 1
# Total de acertos: 8
# 9
# 89.2 % de chance do time azul vencer
# 10.8 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 3
# Redwincount: 7
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 1
# Total de acertos: 9
# 10
# 80.10000000000001 % de chance do time azul vencer
# 19.900000000000002 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 4
# Redwincount: 7
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 1
# Total de acertos: 10
# 11
# 14.499999999999998 % de chance do time azul vencer
# 85.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 4
# Redwincount: 8
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 1
# Total de acertos: 11
# 12
# 42.0 % de chance do time azul vencer
# 57.99999999999999 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 4
# Redwincount: 9
# Eu errei, meeeeeeeee
# Total de erros: 2
# Total de acertos: 11
# 13
# 6.800000000000001 % de chance do time azul vencer
# 93.2 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 4
# Redwincount: 10
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 2
# Total de acertos: 12
# 14
# 69.19999999999999 % de chance do time azul vencer
# 30.8 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 5
# Redwincount: 10
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 2
# Total de acertos: 13
# 15
# 76.1 % de chance do time azul vencer
# 23.9 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 6
# Redwincount: 10
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 2
# Total de acertos: 14
# 16
# 96.89999999999999 % de chance do time azul vencer
# 3.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 7
# Redwincount: 10
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 3
# Total de acertos: 14
# 17
# 52.7 % de chance do time azul vencer
# 47.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 8
# Redwincount: 10
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 3
# Total de acertos: 15
# 18
# 41.4 % de chance do time azul vencer
# 58.599999999999994 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 8
# Redwincount: 11
# Eu errei, meeeeeeeee
# Total de erros: 4
# Total de acertos: 15
# 19
# 99.4 % de chance do time azul vencer
# 0.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 9
# Redwincount: 11
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 4
# Total de acertos: 16
# 20
# 86.5 % de chance do time azul vencer
# 13.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 10
# Redwincount: 11
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 4
# Total de acertos: 17
# 21
# 97.5 % de chance do time azul vencer
# 2.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 11
# Redwincount: 11
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 4
# Total de acertos: 18
# 22
# 58.5 % de chance do time azul vencer
# 41.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 12
# Redwincount: 11
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 5
# Total de acertos: 18
# 23
# 3.6999999999999997 % de chance do time azul vencer
# 96.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 12
# Redwincount: 12
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 19
# 24
# 97.89999999999999 % de chance do time azul vencer
# 2.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 13
# Redwincount: 12
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 20
# 25
# 74.6 % de chance do time azul vencer
# 25.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 14
# Redwincount: 12
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 21
# 26
# 99.5 % de chance do time azul vencer
# 0.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 15
# Redwincount: 12
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 22
# 27
# 87.3 % de chance do time azul vencer
# 12.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 16
# Redwincount: 12
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 23
# 28
# 7.3999999999999995 % de chance do time azul vencer
# 92.60000000000001 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 16
# Redwincount: 13
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 24
# 29
# 76.3 % de chance do time azul vencer
# 23.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 17
# Redwincount: 13
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 25
# 30
# 57.8 % de chance do time azul vencer
# 42.199999999999996 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 18
# Redwincount: 13
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 26
# 31
# 24.6 % de chance do time azul vencer
# 75.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 18
# Redwincount: 14
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 5
# Total de acertos: 27
# 32
# 68.60000000000001 % de chance do time azul vencer
# 31.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 19
# Redwincount: 14
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 6
# Total de acertos: 27
# 33
# 25.1 % de chance do time azul vencer
# 74.9 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 19
# Redwincount: 15
# Eu errei, meeeeeeeee
# Total de erros: 7
# Total de acertos: 27
# 34
# 84.0 % de chance do time azul vencer
# 16.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 20
# Redwincount: 15
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 8
# Total de acertos: 27
# 35
# 76.3 % de chance do time azul vencer
# 23.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 21
# Redwincount: 15
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 28
# 36
# 98.3 % de chance do time azul vencer
# 1.7000000000000002 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 22
# Redwincount: 15
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 29
# 37
# 97.7 % de chance do time azul vencer
# 2.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 23
# Redwincount: 15
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 30
# 38
# 61.6 % de chance do time azul vencer
# 38.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 24
# Redwincount: 15
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 31
# 39
# 2.0 % de chance do time azul vencer
# 98.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 24
# Redwincount: 16
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 32
# 40
# 37.9 % de chance do time azul vencer
# 62.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 24
# Redwincount: 17
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 33
# 41
# 99.9 % de chance do time azul vencer
# 0.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 25
# Redwincount: 17
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 34
# 42
# 99.9 % de chance do time azul vencer
# 0.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 26
# Redwincount: 17
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 35
# 43
# 45.2 % de chance do time azul vencer
# 54.800000000000004 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 26
# Redwincount: 18
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 36
# 44
# 4.7 % de chance do time azul vencer
# 95.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 26
# Redwincount: 19
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 37
# 45
# 99.1 % de chance do time azul vencer
# 0.8999999999999999 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 27
# Redwincount: 19
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 38
# 46
# 21.3 % de chance do time azul vencer
# 78.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 27
# Redwincount: 20
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 39
# 47
# 19.6 % de chance do time azul vencer
# 80.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 27
# Redwincount: 21
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 40
# 48
# 2.0 % de chance do time azul vencer
# 98.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 27
# Redwincount: 22
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 8
# Total de acertos: 41
# 49
# 31.900000000000002 % de chance do time azul vencer
# 68.10000000000001 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 27
# Redwincount: 23
# Eu errei, meeeeeeeee
# Total de erros: 9
# Total de acertos: 41
# 50
# 20.0 % de chance do time azul vencer
# 80.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 27
# Redwincount: 24
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 42
# 51
# 99.8 % de chance do time azul vencer
# 0.2 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 28
# Redwincount: 24
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 43
# 52
# 99.9 % de chance do time azul vencer
# 0.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 29
# Redwincount: 24
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 44
# 53
# 45.2 % de chance do time azul vencer
# 54.800000000000004 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 29
# Redwincount: 25
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 45
# 54
# 4.7 % de chance do time azul vencer
# 95.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 29
# Redwincount: 26
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 46
# 55
# 99.1 % de chance do time azul vencer
# 0.8999999999999999 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 30
# Redwincount: 26
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 47
# 56
# 21.3 % de chance do time azul vencer
# 78.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 30
# Redwincount: 27
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 48
# 57
# 19.6 % de chance do time azul vencer
# 80.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 30
# Redwincount: 28
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 49
# 58
# 2.0 % de chance do time azul vencer
# 98.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 30
# Redwincount: 29
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 9
# Total de acertos: 50
# 59
# 31.900000000000002 % de chance do time azul vencer
# 68.10000000000001 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 30
# Redwincount: 30
# Eu errei, meeeeeeeee
# Total de erros: 10
# Total de acertos: 50
# 60
# 1.9 % de chance do time azul vencer
# 98.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 30
# Redwincount: 31
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 51
# 61
# 9.0 % de chance do time azul vencer
# 91.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 30
# Redwincount: 32
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 52
# 62
# 98.9 % de chance do time azul vencer
# 1.0999999999999999 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 31
# Redwincount: 32
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 53
# 63
# 99.6 % de chance do time azul vencer
# 0.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 32
# Redwincount: 32
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 54
# 64
# 2.8000000000000003 % de chance do time azul vencer
# 97.2 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 32
# Redwincount: 33
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 55
# 65
# 60.4 % de chance do time azul vencer
# 39.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 33
# Redwincount: 33
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 56
# 66
# 76.5 % de chance do time azul vencer
# 23.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 34
# Redwincount: 33
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 57
# 67
# 99.9 % de chance do time azul vencer
# 0.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 35
# Redwincount: 33
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 58
# 68
# 81.0 % de chance do time azul vencer
# 19.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 36
# Redwincount: 33
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 10
# Total de acertos: 59
# 69
# 77.3 % de chance do time azul vencer
# 22.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 37
# Redwincount: 33
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 11
# Total de acertos: 59
# 70
# 77.3 % de chance do time azul vencer
# 22.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 38
# Redwincount: 33
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 12
# Total de acertos: 59
# 71
# 78.3 % de chance do time azul vencer
# 21.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 39
# Redwincount: 33
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 12
# Total de acertos: 60
# 72
# 12.4 % de chance do time azul vencer
# 87.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 39
# Redwincount: 34
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 12
# Total de acertos: 61
# 73
# 26.400000000000002 % de chance do time azul vencer
# 73.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 39
# Redwincount: 35
# Eu errei, meeeeeeeee
# Total de erros: 13
# Total de acertos: 61
# 74
# 99.4 % de chance do time azul vencer
# 0.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 40
# Redwincount: 35
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 13
# Total de acertos: 62
# 75
# 82.69999999999999 % de chance do time azul vencer
# 17.299999999999997 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 41
# Redwincount: 35
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 13
# Total de acertos: 63
# 76
# 11.3 % de chance do time azul vencer
# 88.7 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 41
# Redwincount: 36
# Eu errei, meeeeeeeee
# Total de erros: 14
# Total de acertos: 63
# 77
# 57.699999999999996 % de chance do time azul vencer
# 42.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 42
# Redwincount: 36
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 14
# Total de acertos: 64
# 78
# 0.4 % de chance do time azul vencer
# 99.6 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 42
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 14
# Total de acertos: 65
# 79
# 97.8 % de chance do time azul vencer
# 2.1999999999999997 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 43
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 14
# Total de acertos: 66
# 80
# 99.9 % de chance do time azul vencer
# 0.1 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 44
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 14
# Total de acertos: 67
# 81
# 70.19999999999999 % de chance do time azul vencer
# 29.799999999999997 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 45
# Redwincount: 37
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 15
# Total de acertos: 67
# 82
# 97.6 % de chance do time azul vencer
# 2.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 46
# Redwincount: 37
# Eu errei, meeeeeeeeeeeeeee
# Total de erros: 16
# Total de acertos: 67
# 83
# 94.6 % de chance do time azul vencer
# 5.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 47
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 68
# 84
# 87.2 % de chance do time azul vencer
# 12.8 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 48
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 69
# 85
# 51.7 % de chance do time azul vencer
# 48.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 49
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 70
# 86
# 76.4 % de chance do time azul vencer
# 23.599999999999998 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 50
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 71
# 87
# 97.1 % de chance do time azul vencer
# 2.9000000000000004 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 51
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 72
# 88
# 96.0 % de chance do time azul vencer
# 4.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 52
# Redwincount: 37
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 73
# 89
# 5.5 % de chance do time azul vencer
# 94.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 52
# Redwincount: 38
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 74
# 90
# 76.1 % de chance do time azul vencer
# 23.9 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 53
# Redwincount: 38
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 75
# 91
# 0.6 % de chance do time azul vencer
# 99.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 53
# Redwincount: 39
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 76
# 92
# 9.6 % de chance do time azul vencer
# 90.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 53
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 77
# 93
# 94.6 % de chance do time azul vencer
# 5.4 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 54
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 78
# 94
# 87.2 % de chance do time azul vencer
# 12.8 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 55
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 79
# 95
# 51.7 % de chance do time azul vencer
# 48.3 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 56
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 80
# 96
# 76.4 % de chance do time azul vencer
# 23.599999999999998 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 57
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 81
# 97
# 97.1 % de chance do time azul vencer
# 2.9000000000000004 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 58
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 82
# 98
# 96.0 % de chance do time azul vencer
# 4.0 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 59
# Redwincount: 40
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 83
# 99
# 5.5 % de chance do time azul vencer
# 94.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 59
# Redwincount: 41
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 84
# 100
# 92.2 % de chance do time azul vencer
# 7.8 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 60
# Redwincount: 41
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 85
# 101
# 5.5 % de chance do time azul vencer
# 94.5 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 0
# Bluewincount: 60
# Redwincount: 42
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 86
# 102
# 95.6 % de chance do time azul vencer
# 4.3999999999999995 % de chance do time vermelho vencer
# Acho que o vencedor foi o: 1
# Bluewincount: 61
# Redwincount: 42
# Hmmm analizando o resultado real da partida, eu acertei hihi
# Total de erros: 16
# Total de acertos: 87
